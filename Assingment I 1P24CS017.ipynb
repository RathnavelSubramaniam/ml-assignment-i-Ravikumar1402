# %% [markdown]
# Assignment - 1

# %% [markdown]
# 1.	This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %% [markdown]
# Importing the ISLP and other packages

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from ISLP import load_data

# %% [markdown]
# Adding the Dataset

# %%
Auto = load_data("Auto")
Auto
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
# ...

# %% [markdown]
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
Auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# dtype: object

# %%
Quali = Auto.select_dtypes(include=['object'])
Quali
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
Quanti = Auto.select_dtypes(include=['float64', 'int64'])
Quanti
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0          86    2790
# vw pickup                  44.0          4          97.0          52    2130
# dodge rampage              32.0          4         135.0          84    2295
# ford ranger                28.0          4         120.0          79    2625
# chevy s-10                 31.0          4         119.0          82    2720
#
# ...

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer this using the range() function.

# %%
column = ['cylinders','weight','mpg','displacement','acceleration','year','horsepower']
min = Auto[column].min()
max = Auto[column].max()
print(f"Range of {column}: {max}, {min}")
# Out:
# Range of ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders          8.0
# weight          5140.0
# mpg               46.6
# displacement     455.0
# acceleration      24.8
# year              82.0
# horsepower       230.0
# dtype: float64, cylinders          3.0
# weight          1613.0
# mpg                9.0
# displacement      68.0
# acceleration       8.0
# year              70.0
# horsepower        46.0
# dtype: float64

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative predictor?

# %%
Mean = Auto[column].mean()
Stdev = Auto[column].std()
print(f"Mean of: {column}: {Mean} , Std Dev of: {column}: {Stdev}")
# Out:
# Mean of: ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders          5.471939
# weight          2977.584184
# mpg               23.445918
# displacement     194.411990
# acceleration      15.541327
# year              75.979592
# horsepower       104.469388
# dtype: float64 , Std Dev of: ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders         1.705783
# weight          849.402560
# mpg               7.805007
# displacement    104.644004
# acceleration      2.758864
# year              3.683737
# horsepower       38.491160
# dtype: float64

# %% [markdown]
# (d)	 Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
data = Auto.drop(Auto.index[9:85])

Mean = data[column].mean()
Stdev = data[column].std()
Max = data[column].max()
Min = data[column].min()
print(f"Range of {column}: {Max}, {Min}")
print(f"Mean of {column}: {Mean}, Std Dev of {column}: {Stdev}")
# Out:
# Range of ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders          8.0
# weight          4952.0
# mpg               46.6
# displacement     455.0
# acceleration      24.6
# year              82.0
# horsepower       230.0
# dtype: float64, cylinders          3.0
# weight          1755.0
# mpg               11.0
# displacement      68.0
# acceleration       9.5
# year              70.0
# horsepower        46.0
# dtype: float64
# Mean of ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders          5.274021
# weight          2881.505338
# mpg               25.041637
# displacement     179.373665
# acceleration      15.738790
# year              77.508897
# horsepower        98.715302
# dtype: float64, Std Dev of ['cylinders', 'weight', 'mpg', 'displacement', 'acceleration', 'year', 'horsepower']: cylinders         1.632155
# weight          792.548494
# mpg               7.912874
# ...

# %% [markdown]
# (e)	Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
sns.boxplot(x=Auto['mpg'], y=Auto['cylinders'])
plt.title("Boxplot of MPG by cylinders")
plt.show()

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer

# %%
sns.lineplot(x='mpg', y='displacement', data=Auto)
plt.title('MPG vs Displacement - Line Plot')
plt.xlabel('Miles Per Gallon')
plt.ylabel('Displacement')
plt.show()

# %%
sns.lineplot(x='mpg', y='weight', data=Auto)
plt.title('MPG vs Weight - Line Plot')
plt.xlabel('Miles Per Gallon')
plt.ylabel('Weight')
plt.show()

# %%
sns.lineplot(x='mpg', y='acceleration', data=Auto)
plt.title('MPG vs Acceleration - Line Plot')
plt.xlabel('Miles Per Gallon')
plt.ylabel('Acceleration')
plt.show()

# %%
sns.lineplot(x='mpg', y='year', data=Auto)
plt.title('MPG vs Year - Line Plot')
plt.xlabel('Miles Per Gallon')
plt.ylabel('Year')
plt.show()

# %% [markdown]
# The plots suggest that weight, horsepower, displacement, and cylinders are strong predictors of mpg. Model year and origin may also contribute moderately. Acceleration seems less useful based on visual inspection.
